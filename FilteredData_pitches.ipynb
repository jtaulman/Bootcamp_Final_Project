# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %%
df = pd.read_csv('pitches.csv', usecols=['ab_id','pitch_type','code','type','b_count','s_count','outs','on_1b','on_2b','on_3b','px','pz','zone','start_speed','end_speed'])
df
# Out:
#             px     pz  start_speed  end_speed  zone code type pitch_type  \
# 0        0.416  2.963         92.9       84.1   3.0    C    S         FF
# 1       -0.191  2.347         92.8       84.1   5.0    S    S         FF
# 2       -0.518  3.284         94.1       85.2   1.0    F    S         FF
# 3       -0.641  1.221         91.0       84.0  13.0    B    B         FF
# 4       -1.821  2.083         75.4       69.6  13.0    B    B         CU
# ...        ...    ...          ...        ...   ...  ...  ...        ...
# 1048570 -0.777  1.301         73.5       68.4  13.0    B    B         KN
# 1048571 -0.276  1.986         78.1       72.0   7.0    X    X         KN
# 1048572 -0.127  4.070         79.0       73.6  11.0    B    B         KN
# 1048573  0.163  3.084         71.6       66.5   2.0    C    S         KN
# 1048574 -0.625  2.864         66.4       61.6   1.0    C    S         EP
#
#               ab_id  b_count  s_count  outs  on_1b  on_2b  on_3b
# ...

# %%
df.count()
# Out:
# px             1047019
# pz             1047019
# start_speed    1047028
# end_speed      1047028
# zone           1047019
# code           1042856
# type           1048575
# pitch_type     1047019
# ab_id          1048575
# b_count        1048575
# s_count        1048575
# outs           1048575
# on_1b          1048575
# on_2b          1048575
# on_3b          1048575
# dtype: int64

# %%
pitches_df = df.dropna()

# %%
pitches_df.count()
# Out:
# px             1041304
# pz             1041304
# start_speed    1041304
# end_speed      1041304
# zone           1041304
# code           1041304
# type           1041304
# pitch_type     1041304
# ab_id          1041304
# b_count        1041304
# s_count        1041304
# outs           1041304
# on_1b          1041304
# on_2b          1041304
# on_3b          1041304
# dtype: int64

# %%
pitches_df[['ab_id','pitch_type','code','type','b_count','s_count','outs','on_1b','on_2b','on_3b','px','pz','zone','start_speed','end_speed']]
# Out:
#               ab_id pitch_type code type  b_count  s_count  outs  on_1b  \
# 0        2015000001         FF    C    S        0        0     0      0
# 1        2015000001         FF    S    S        0        1     0      0
# 2        2015000001         FF    F    S        0        2     0      0
# 3        2015000001         FF    B    B        0        2     0      0
# 4        2015000001         CU    B    B        1        2     0      0
# ...             ...        ...  ...  ...      ...      ...   ...    ...
# 1048570  2016089829         KN    B    B        2        2     1      0
# 1048571  2016089829         KN    X    X        3        2     1      0
# 1048572  2016089830         KN    B    B        0        0     2      0
# 1048573  2016089830         KN    C    S        1        0     2      0
# 1048574  2016089830         EP    C    S        1        1     2      0
#
#          on_2b  on_3b     px     pz  zone  start_speed  end_speed
# ...

# %%
pitches_df.dtypes
# Out:
# px             float64
# pz             float64
# start_speed    float64
# end_speed      float64
# zone           float64
# code            object
# type            object
# pitch_type      object
# ab_id            int64
# b_count          int64
# s_count          int64
# outs             int64
# on_1b            int64
# on_2b            int64
# on_3b            int64
# dtype: object

# %%
pitches_df.to_csv (r'C:\Users\New\Desktop\BootcampUA\Final Project\filtered_pitches.csv', index = False, header=True)

print (pitches_df)
# Out:
#             px     pz  start_speed  end_speed  zone code type pitch_type  \
# 0        0.416  2.963         92.9       84.1   3.0    C    S         FF
# 1       -0.191  2.347         92.8       84.1   5.0    S    S         FF
# 2       -0.518  3.284         94.1       85.2   1.0    F    S         FF
# 3       -0.641  1.221         91.0       84.0  13.0    B    B         FF
# 4       -1.821  2.083         75.4       69.6  13.0    B    B         CU
# ...        ...    ...          ...        ...   ...  ...  ...        ...
# 1048570 -0.777  1.301         73.5       68.4  13.0    B    B         KN
# 1048571 -0.276  1.986         78.1       72.0   7.0    X    X         KN
# 1048572 -0.127  4.070         79.0       73.6  11.0    B    B         KN
# 1048573  0.163  3.084         71.6       66.5   2.0    C    S         KN
# 1048574 -0.625  2.864         66.4       61.6   1.0    C    S         EP
#
#               ab_id  b_count  s_count  outs  on_1b  on_2b  on_3b
# ...
